# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Análisis exploratorio
# ## 1.1 Integralidad de la información

# %%
data=pd.read_csv(r"C:\Users\Usuario\Ciencia de datos\MLPython\python-ml-course-master\datasets\titanic\titanic3.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# El primer paso que realizo es un análisis de los datos, entendiendo de manera adecuada la información que contiene cada una de als columnas, es necesario ajustar el tipo de variable de cada feature para que sea correspondiente con la naturaleza de la columna.
#
# En este caso, las variable pclass, correspondiente a la clase del pasajero, cuya naturaleza es categorica será cambiada a object, la variable survived, correspondiente a si el pasajero sobrevivió o no, cuya naturaleza es booleana, será cambiado de la misma.
#
# Esta transformación será realizada a continuación

# %%
convert_dict = {'survived': bool,
                'pclass': object,
                'body': object}
data[["survived", "pclass", 'body']] = data[["survived", "pclass", 'body']].astype (convert_dict)
data[['pclass','sex','ticket', 'cabin', 'embarked', 'boat','home.dest' ]] =data[['pclass','sex','ticket', 'cabin', 'embarked', 'boat','home.dest' ]].astype("category")

# %% [markdown]
# Además, en este punto es necesario conocer si existen datos nulos en el dataset para empezar a identificar la manera en la que deben ser tratados.

# %%
data.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %% [markdown]
# Como se puede observar, algunas columnas tienen datos nulos, los valores faltantes en columna de edad serán reemplazados por el promedio, los registros que tienen datos faltantes en la columna fare y embarked serán eliminados, además, las columnas cabin y home.dest serán eliminadas
#
# Por otro lado, la columna boat, correspondiente al bote salvavidas que utilizó y la columna body, correspondiente al número de cuerpo si es que fue hallado, se sospecha tienen relación directa con la supervivencia del pasajero, por lo tanto, serán reemplazados los espacios nulos con un valor que no afecte el desempeño del modelo

# %%
## Exploración y visualización de los primeros 50 datos
## esto se hace con el fin de comprobar la integridad de la información
data.head(50)
# Out:
#    pclass  survived                                               name  \
# 0       1      True                      Allen, Miss. Elisabeth Walton
# 1       1      True                     Allison, Master. Hudson Trevor
# 2       1     False                       Allison, Miss. Helen Loraine
# 3       1     False               Allison, Mr. Hudson Joshua Creighton
# 4       1     False    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5       1      True                                Anderson, Mr. Harry
# 6       1      True                  Andrews, Miss. Kornelia Theodosia
# 7       1     False                             Andrews, Mr. Thomas Jr
# 8       1      True      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9       1     False                            Artagaveytia, Mr. Ramon
# 10      1     False                             Astor, Col. John Jacob
# 11      1      True  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12      1      True                      Aubart, Mme. Leontine Pauline
# 13      1      True                       Barber, Miss. Ellen "Nellie"
# 14      1      True               Barkworth, Mr. Algernon Henry Wilson
# 15      1     False                                Baumann, Mr. John D
# 16      1     False                           Baxter, Mr. Quigg Edmond
# 17      1      True    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18      1      True                              Bazzani, Miss. Albina
# 19      1     False                               Beattie, Mr. Thomson
# 20      1      True                      Beckwith, Mr. Richard Leonard
# 21      1      True   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22      1      True                              Behr, Mr. Karl Howell
# 23      1      True                              Bidois, Miss. Rosalie
# 24      1      True                                  Bird, Miss. Ellen
# 25      1     False                                Birnbaum, Mr. Jakob
# 26      1      True                            Bishop, Mr. Dickinson H
# 27      1      True            Bishop, Mrs. Dickinson H (Helen Walton)
# 28      1      True                             Bissette, Miss. Amelia
# 29      1      True          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 30      1     False                       Blackwell, Mr. Stephen Weart
# 31      1      True                                   Blank, Mr. Henry
# 32      1      True                            Bonnell, Miss. Caroline
# 33      1      True                           Bonnell, Miss. Elizabeth
# 34      1     False                           Borebank, Mr. John James
# 35      1      True                           Bowen, Miss. Grace Scott
# 36      1      True                        Bowerman, Miss. Elsie Edith
# 37      1      True      Bradley, Mr. George ("George Arthur Brayton")
# 38      1     False                            Brady, Mr. John Bertram
# 39      1     False                                 Brandeis, Mr. Emil
# 40      1     False                          Brewe, Dr. Arthur Jackson
# 41      1      True          Brown, Mrs. James Joseph (Margaret Tobin)
# 42      1      True     Brown, Mrs. John Murray (Caroline Lane Lamson)
# 43      1      True    Bucknell, Mrs. William Robert (Emma Eliza Ward)
# 44      1      True                    Burns, Miss. Elizabeth Margaret
# 45      1     False                  Butt, Major. Archibald Willingham
# 46      1     False                              Cairns, Mr. Alexander
# 47      1      True                  Calderhead, Mr. Edward Pennington
# 48      1      True   Candee, Mrs. Edward (Helen Churchill Hungerford)
# 49      1      True                 Cardeza, Mr. Thomas Drake Martinez
#
#        sex      age  sibsp  parch    ticket      fare        cabin embarked  \
# 0   female  29.0000      0      0     24160  211.3375           B5        S
# 1     male   0.9167      1      2    113781  151.5500      C22 C26        S
# 2   female   2.0000      1      2    113781  151.5500      C22 C26        S
# 3     male  30.0000      1      2    113781  151.5500      C22 C26        S
# 4   female  25.0000      1      2    113781  151.5500      C22 C26        S
# 5     male  48.0000      0      0     19952   26.5500          E12        S
# 6   female  63.0000      1      0     13502   77.9583           D7        S
# 7     male  39.0000      0      0    112050    0.0000          A36        S
# 8   female  53.0000      2      0     11769   51.4792         C101        S
# 9     male  71.0000      0      0  PC 17609   49.5042          NaN        C
# 10    male  47.0000      1      0  PC 17757  227.5250      C62 C64        C
# 11  female  18.0000      1      0  PC 17757  227.5250      C62 C64        C
# 12  female  24.0000      0      0  PC 17477   69.3000          B35        C
# 13  female  26.0000      0      0     19877   78.8500          NaN        S
# 14    male  80.0000      0      0     27042   30.0000          A23        S
# 15    male      NaN      0      0  PC 17318   25.9250          NaN        S
# 16    male  24.0000      0      1  PC 17558  247.5208      B58 B60        C
# 17  female  50.0000      0      1  PC 17558  247.5208      B58 B60        C
# 18  female  32.0000      0      0     11813   76.2917          D15        C
# 19    male  36.0000      0      0     13050   75.2417           C6        C
# 20    male  37.0000      1      1     11751   52.5542          D35        S
# 21  female  47.0000      1      1     11751   52.5542          D35        S
# 22    male  26.0000      0      0    111369   30.0000         C148        C
# 23  female  42.0000      0      0  PC 17757  227.5250          NaN        C
# 24  female  29.0000      0      0  PC 17483  221.7792          C97        S
# 25    male  25.0000      0      0     13905   26.0000          NaN        C
# 26    male  25.0000      1      0     11967   91.0792          B49        C
# 27  female  19.0000      1      0     11967   91.0792          B49        C
# 28  female  35.0000      0      0  PC 17760  135.6333          C99        S
# 29    male  28.0000      0      0    110564   26.5500          C52        S
# 30    male  45.0000      0      0    113784   35.5000            T        S
# 31    male  40.0000      0      0    112277   31.0000          A31        C
# 32  female  30.0000      0      0     36928  164.8667           C7        S
# 33  female  58.0000      0      0    113783   26.5500         C103        S
# 34    male  42.0000      0      0    110489   26.5500          D22        S
# 35  female  45.0000      0      0  PC 17608  262.3750          NaN        C
# 36  female  22.0000      0      1    113505   55.0000          E33        S
# 37    male      NaN      0      0    111427   26.5500          NaN        S
# 38    male  41.0000      0      0    113054   30.5000          A21        S
# 39    male  48.0000      0      0  PC 17591   50.4958          B10        C
# 40    male      NaN      0      0    112379   39.6000          NaN        C
# 41  female  44.0000      0      0  PC 17610   27.7208           B4        C
# 42  female  59.0000      2      0     11769   51.4792         C101        S
# 43  female  60.0000      0      0     11813   76.2917          D15        C
# 44  female  41.0000      0      0     16966  134.5000          E40        C
# 45    male  45.0000      0      0    113050   26.5500          B38        S
# 46    male      NaN      0      0    113798   31.0000          NaN        S
# 47    male  42.0000      0      0  PC 17476   26.2875          E24        S
# 48  female  53.0000      0      0  PC 17606   27.4458          NaN        C
# 49    male  36.0000      0      1  PC 17755  512.3292  B51 B53 B55        C
#
#    boat body                                       home.dest
# 0     2  NaN                                    St Louis, MO
# 1    11  NaN                 Montreal, PQ / Chesterville, ON
# 2   NaN  NaN                 Montreal, PQ / Chesterville, ON
# 3   NaN  135                 Montreal, PQ / Chesterville, ON
# 4   NaN  NaN                 Montreal, PQ / Chesterville, ON
# 5     3  NaN                                    New York, NY
# 6    10  NaN                                      Hudson, NY
# 7   NaN  NaN                                     Belfast, NI
# 8     D  NaN                             Bayside, Queens, NY
# 9   NaN   22                             Montevideo, Uruguay
# 10  NaN  124                                    New York, NY
# 11    4  NaN                                    New York, NY
# 12    9  NaN                                   Paris, France
# 13    6  NaN                                             NaN
# 14    B  NaN                                   Hessle, Yorks
# 15  NaN  NaN                                    New York, NY
# 16  NaN  NaN                                    Montreal, PQ
# 17    6  NaN                                    Montreal, PQ
# 18    8  NaN                                             NaN
# 19    A  NaN                                    Winnipeg, MN
# 20    5  NaN                                    New York, NY
# 21    5  NaN                                    New York, NY
# 22    5  NaN                                    New York, NY
# 23    4  NaN                                             NaN
# 24    8  NaN                                             NaN
# 25  NaN  148                               San Francisco, CA
# 26    7  NaN                                    Dowagiac, MI
# 27    7  NaN                                    Dowagiac, MI
# 28    8  NaN                                             NaN
# 29    D  NaN              Stockholm, Sweden / Washington, DC
# 30  NaN  NaN                                     Trenton, NJ
# 31    7  NaN                                  Glen Ridge, NJ
# 32    8  NaN                                  Youngstown, OH
# 33    8  NaN               Birkdale, England Cleveland, Ohio
# 34  NaN  NaN                           London / Winnipeg, MB
# 35    4  NaN                                 Cooperstown, NY
# 36    6  NaN                St Leonards-on-Sea, England Ohio
# 37    9  NaN                                 Los Angeles, CA
# 38  NaN  NaN                                     Pomeroy, WA
# 39  NaN  208                                       Omaha, NE
# 40  NaN  NaN                                Philadelphia, PA
# 41    6  NaN                                      Denver, CO
# 42    D  NaN                                     Belmont, MA
# 43    8  NaN                                Philadelphia, PA
# 44    3  NaN                                             NaN
# 45  NaN  NaN                                  Washington, DC
# 46  NaN  NaN                                             NaN
# 47    5  NaN                                    New York, NY
# 48    6  NaN                                  Washington, DC
# 49    3  NaN  Austria-Hungary / Germantown, Philadelphia, PA

# %%
## Exploración y visualización de los últimos 50 datos
## esto se hace con el fin de comprobar la integridad de la información
data.tail(50)
# Out:
#      pclass  survived                                               name  \
# 1259      3     False                                Turcin, Mr. Stjepan
# 1260      3      True                            Turja, Miss. Anna Sofia
# 1261      3      True                             Turkula, Mrs. (Hedwig)
# 1262      3     False                van Billiard, Master. James William
# 1263      3     False                  van Billiard, Master. Walter John
# 1264      3     False                    van Billiard, Mr. Austin Blyler
# 1265      3     False                          Van Impe, Miss. Catharina
# 1266      3     False                        Van Impe, Mr. Jean Baptiste
# 1267      3     False  Van Impe, Mrs. Jean Baptiste (Rosalie Paula Go...
# 1268      3     False                        van Melkebeke, Mr. Philemon
# 1269      3     False                   Vande Velde, Mr. Johannes Joseph
# 1270      3     False                     Vande Walle, Mr. Nestor Cyriel
# 1271      3     False                        Vanden Steen, Mr. Leo Peter
# 1272      3     False                        Vander Cruyssen, Mr. Victor
# 1273      3     False                 Vander Planke, Miss. Augusta Maria
# 1274      3     False                          Vander Planke, Mr. Julius
# 1275      3     False                    Vander Planke, Mr. Leo Edmondus
# 1276      3     False  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1277      3      True                               Vartanian, Mr. David
# 1278      3     False                             Vendel, Mr. Olof Edvin
# 1279      3     False               Vestrom, Miss. Hulda Amanda Adolfina
# 1280      3     False                                    Vovk, Mr. Janko
# 1281      3     False                               Waelens, Mr. Achille
# 1282      3     False                                Ware, Mr. Frederick
# 1283      3     False                        Warren, Mr. Charles William
# 1284      3     False                                  Webber, Mr. James
# 1285      3     False                                Wenzel, Mr. Linhart
# 1286      3      True    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287      3     False                   Widegren, Mr. Carl/Charles Peter
# 1288      3     False                          Wiklund, Mr. Jakob Alfred
# 1289      3     False                            Wiklund, Mr. Karl Johan
# 1290      3      True                   Wilkes, Mrs. James (Ellen Needs)
# 1291      3     False                   Willer, Mr. Aaron ("Abi Weller")
# 1292      3     False                                 Willey, Mr. Edward
# 1293      3     False                  Williams, Mr. Howard Hugh "Harry"
# 1294      3     False                               Williams, Mr. Leslie
# 1295      3     False                                Windelov, Mr. Einar
# 1296      3     False                                   Wirz, Mr. Albert
# 1297      3     False                             Wiseman, Mr. Phillippe
# 1298      3     False                          Wittevrongel, Mr. Camille
# 1299      3     False                                Yasbeck, Mr. Antoni
# 1300      3      True            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301      3     False                               Youseff, Mr. Gerious
# 1302      3     False                                  Yousif, Mr. Wazli
# 1303      3     False                              Yousseff, Mr. Gerious
# 1304      3     False                               Zabour, Miss. Hileni
# 1305      3     False                              Zabour, Miss. Thamine
# 1306      3     False                          Zakarian, Mr. Mapriededer
# 1307      3     False                                Zakarian, Mr. Ortin
# 1308      3     False                                 Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch            ticket     fare cabin embarked  \
# 1259    male  36.0      0      0            349247   7.8958   NaN        S
# 1260  female  18.0      0      0              4138   9.8417   NaN        S
# 1261  female  63.0      0      0              4134   9.5875   NaN        S
# 1262    male   NaN      1      1          A/5. 851  14.5000   NaN        S
# 1263    male  11.5      1      1          A/5. 851  14.5000   NaN        S
# 1264    male  40.5      0      2          A/5. 851  14.5000   NaN        S
# 1265  female  10.0      0      2            345773  24.1500   NaN        S
# 1266    male  36.0      1      1            345773  24.1500   NaN        S
# 1267  female  30.0      1      1            345773  24.1500   NaN        S
# 1268    male   NaN      0      0            345777   9.5000   NaN        S
# 1269    male  33.0      0      0            345780   9.5000   NaN        S
# 1270    male  28.0      0      0            345770   9.5000   NaN        S
# 1271    male  28.0      0      0            345783   9.5000   NaN        S
# 1272    male  47.0      0      0            345765   9.0000   NaN        S
# 1273  female  18.0      2      0            345764  18.0000   NaN        S
# 1274    male  31.0      3      0            345763  18.0000   NaN        S
# 1275    male  16.0      2      0            345764  18.0000   NaN        S
# 1276  female  31.0      1      0            345763  18.0000   NaN        S
# 1277    male  22.0      0      0              2658   7.2250   NaN        C
# 1278    male  20.0      0      0            350416   7.8542   NaN        S
# 1279  female  14.0      0      0            350406   7.8542   NaN        S
# 1280    male  22.0      0      0            349252   7.8958   NaN        S
# 1281    male  22.0      0      0            345767   9.0000   NaN        S
# 1282    male   NaN      0      0            359309   8.0500   NaN        S
# 1283    male   NaN      0      0        C.A. 49867   7.5500   NaN        S
# 1284    male   NaN      0      0  SOTON/OQ 3101316   8.0500   NaN        S
# 1285    male  32.5      0      0            345775   9.5000   NaN        S
# 1286  female  38.0      0      0              2688   7.2292   NaN        C
# 1287    male  51.0      0      0            347064   7.7500   NaN        S
# 1288    male  18.0      1      0           3101267   6.4958   NaN        S
# 1289    male  21.0      1      0           3101266   6.4958   NaN        S
# 1290  female  47.0      1      0            363272   7.0000   NaN        S
# 1291    male   NaN      0      0              3410   8.7125   NaN        S
# 1292    male   NaN      0      0     S.O./P.P. 751   7.5500   NaN        S
# 1293    male   NaN      0      0          A/5 2466   8.0500   NaN        S
# 1294    male  28.5      0      0             54636  16.1000   NaN        S
# 1295    male  21.0      0      0  SOTON/OQ 3101317   7.2500   NaN        S
# 1296    male  27.0      0      0            315154   8.6625   NaN        S
# 1297    male   NaN      0      0        A/4. 34244   7.2500   NaN        S
# 1298    male  36.0      0      0            345771   9.5000   NaN        S
# 1299    male  27.0      1      0              2659  14.4542   NaN        C
# 1300  female  15.0      1      0              2659  14.4542   NaN        C
# 1301    male  45.5      0      0              2628   7.2250   NaN        C
# 1302    male   NaN      0      0              2647   7.2250   NaN        C
# 1303    male   NaN      0      0              2627  14.4583   NaN        C
# 1304  female  14.5      1      0              2665  14.4542   NaN        C
# 1305  female   NaN      1      0              2665  14.4542   NaN        C
# 1306    male  26.5      0      0              2656   7.2250   NaN        C
# 1307    male  27.0      0      0              2670   7.2250   NaN        C
# 1308    male  29.0      0      0            315082   7.8750   NaN        S
#
#        boat body                       home.dest
# 1259    NaN  NaN                             NaN
# 1260     15  NaN                             NaN
# 1261     15  NaN                             NaN
# 1262    NaN  NaN                             NaN
# 1263    NaN    1                             NaN
# 1264    NaN  255                             NaN
# 1265    NaN  NaN                             NaN
# 1266    NaN  NaN                             NaN
# 1267    NaN  NaN                             NaN
# 1268    NaN  NaN                             NaN
# 1269    NaN  NaN                             NaN
# 1270    NaN  NaN                             NaN
# 1271    NaN  NaN                             NaN
# 1272    NaN  NaN                             NaN
# 1273    NaN  NaN                             NaN
# 1274    NaN  NaN                             NaN
# 1275    NaN  NaN                             NaN
# 1276    NaN  NaN                             NaN
# 1277  13 15  NaN                             NaN
# 1278    NaN  NaN                             NaN
# 1279    NaN  NaN                             NaN
# 1280    NaN  NaN                             NaN
# 1281    NaN  NaN  Antwerp, Belgium / Stanton, OH
# 1282    NaN  NaN                             NaN
# 1283    NaN  NaN                             NaN
# 1284    NaN  NaN                             NaN
# 1285    NaN  298                             NaN
# 1286      C  NaN                             NaN
# 1287    NaN  NaN                             NaN
# 1288    NaN  314                             NaN
# 1289    NaN  NaN                             NaN
# 1290    NaN  NaN                             NaN
# 1291    NaN  NaN                             NaN
# 1292    NaN  NaN                             NaN
# 1293    NaN  NaN                             NaN
# 1294    NaN   14                             NaN
# 1295    NaN  NaN                             NaN
# 1296    NaN  131                             NaN
# 1297    NaN  NaN                             NaN
# 1298    NaN  NaN                             NaN
# 1299      C  NaN                             NaN
# 1300    NaN  NaN                             NaN
# 1301    NaN  312                             NaN
# 1302    NaN  NaN                             NaN
# 1303    NaN  NaN                             NaN
# 1304    NaN  328                             NaN
# 1305    NaN  NaN                             NaN
# 1306    NaN  304                             NaN
# 1307    NaN  NaN                             NaN
# 1308    NaN  NaN                             NaN

# %% [markdown]
# Con la finalidad de comprender con mejor profundidad nuestro problema, es importante entender que tan balanceada esta la muestra, en este caso nuestra clasificación es la supervivencia (columna "survived"), la cual puede tomar solamente valores de True y False

# %%
data.survived.value_counts()
# Out:
# False    809
# True     500
# Name: survived, dtype: int64

# %% [markdown]
# Incluso si la muestra no está lo suficientemente balanceada, parece que tenemos suficiente información de ambas categorías para que el modelo quede entrenado sin sesgo, en caso tal de que el modelo no se comporte de la manera esperada, procederemos a balancear la muestra

# %% [markdown]
# ## 1.1 Entendiendo el sistema
#
# Para llegar a una decisión acertada y un análisis que genere valor en el momento de tomar decisiones de negocio, es necesario entender la naturaleza del fenómeno que se está estudiando y entender como adquieren sentido los datos contextualizados en el sistema.
#
# En este caso particular, las variables de estudio no son temporales, además pertenecientes en gran proporción a datos socio demográficos de los pasajeros y su ubicación y posición dentro de la embarcación.
# El conocimiento del origen de la información y su significado nos ayuda a encaminar de manera adecuada el tratamiento de datos.

# %%
f, axes = plt.subplots(2, 2, figsize=(12, 12))
sns.countplot(x= "survived", data=data, ax=axes[0,0])
sns.countplot(x="pclass", data=data, ax= axes[0,1])
sns.countplot(x="embarked", data= data, ax=axes[1,0])
sns.countplot(x="sex", data= data, ax=axes[1,1])

plt.figure(figsize=(12,6))
sns.countplot(x="boat" ,data=data)

#De esta manera añadimos un gráfico de pie en caso de necesitarlo
#clase= pd.DataFrame(data["pclass"].value_counts())
#plt.figure(figsize=(6,6))
#plt.pie((clase["pclass"]), labels=clase.index, autopct= "%1.1f%%")

# %% [markdown]
# En las gráficas anteriormente presentadas podemos visualizar como se distribuyen los datos en las diferentes variables categoricas que decidimos utilizar anteriormente, de esta manera podemos clarificar como estaban distribuidos los datos.
#
# Tener conocimiento de esto es altamente importante en el momento de tratar espacios vacíos y para el tratamiento de valores atípicos.

# %% [markdown]
# #### Resumen diagnóstico del Dataset:
# * La información contenida en el Dataset es de buena calidad en la mayoría de las columnas, tiene pocos datos lo cual restringe la posibilidad de utilizar modelos más robustos como modelos de deep learning y técnicas de ensamblaje.
# * La variable objetivo, aunque no está balanceada, tiene suficientes datos en cada categoría, en principio se hará una primera iteración del modelo con los datos tal como están, sin embargo, se intentará una mejora del rendimiento del mismo balanceando los datos
# * Incluso contando solo con información categorica y sociodemografica, el Dataset no presenta valores absurdos en ninguna de las columnas anteriormente representadas (una edad de mil años, un número de familiares dentro de la embarcación demasiado grande, etc), esto se corroborará revisando a profundidad los outliers en los diagramas de caja.

# %% [markdown]
# # 2. Examinación estadistica
# ## 2.1 Descripción básica

# %%
#Descripción de las variables numericas
data.describe()
# Out:
#                age        sibsp        parch         fare
# count  1046.000000  1309.000000  1309.000000  1308.000000
# mean     29.881135     0.498854     0.385027    33.295479
# std      14.413500     1.041658     0.865560    51.758668
# min       0.166700     0.000000     0.000000     0.000000
# 25%      21.000000     0.000000     0.000000     7.895800
# 50%      28.000000     0.000000     0.000000    14.454200
# 75%      39.000000     1.000000     0.000000    31.275000
# max      80.000000     8.000000     9.000000   512.329200

# %%
#Descripción de las variables categoricas
data.describe(include=["category"])
# Out:
#         pclass   sex    ticket        cabin embarked boat     home.dest
# count     1309  1309      1309          295     1307  486           745
# unique       3     2       929          186        3   27           369
# top          3  male  CA. 2343  C23 C25 C27        S   13  New York, NY
# freq       709   843        11            6      914   39            64

# %% [markdown]
# #### Hechos para resaltar:
# * Las variables numericas presentan una dispersión considerable (mayor al 50% en todas las columnas), esto lo podemos observar y analizar en las desviaciones estándar.
# * El conteo de las variables numericas es bastante homogeneo excepto por la columna body, la cual no tiene datos para los cuerpos no encontrados (la importancia del contexto de negocio), además, hay algunos valores vacíos en la columna de edad.
# * Para las variables categoricas, no hay un conteo homogeneo, por lo cual, como se explico en un paso anterior, se procederá a eliminar las columnas de "cabin" y "home.dest" en aras de conseguir un modelo preciso, por el contrario, la variable boat se presume está directamente relacionada con el deceso de los tripulantes del Titanic, por lo cual será tenida en cuenta en el analisis.
# * Por otro lado, las variables numericas tienen máximos y mínimos razonables, para descartar absurdos o errores relacionados con la colecta de los datos.

# %% [markdown]
# ## 2.2 Análisis gráfico

# %%
f, axes =plt.subplots(2, 2, figsize=(14, 14))
k=int(np.ceil(1+ np.log2(len(data))))
sns.distplot(data["age"], bins= k, kde=True, ax=axes[0,0])
sns.distplot(data["sibsp"], bins= k, kde=True, ax=axes[0,1])
sns.distplot(data["parch"], bins= 9, ax=axes[1,0])
sns.distplot(data["fare"], bins= k+4, kde=True, ax=axes[1,1])
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Sobre las distribuciones:
# * No hay valores absurdos (edades negativas, cantidades negativas o absurdamente grandes de familiares a bordo)
# * Las distribuciones no tienen colas pesadas
# * La distribución de hermanos y parientes a bordo está concentrada entre 0 y 2 personas en su mayoría.

# %%
sns.pairplot(data= data, hue='survived')
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\seaborn\distributions.py:369: UserWarning: Default bandwidth for data is 0; skipping density estimation.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Sobre el análisis gráfico por estado:
# * Se observa un pico particular que relaciona directamente los decesos del fenomeno con la clase en la cual iban ubicados los pasajeros, del resto de las distrubuciones se obersvan dos particularidades, la primera es que de todos los sobrevivientes, ninguno tenía padres/hijos a bordo, la segunda es que solo hay número de cuerpo para los que sobrevivieron, lo cual es completamente coherente con la naturaleza del fenómeno.
# * No se observan correlaciones directas que de antemano inviten a descartar alguna variable. Aunque se examinará la correlación con más detalle más adelante para cerciorarse de que todas las variables aportan información útil.

# %%
f, axes =plt.subplots(3, 2, figsize=(14, 14))
sns.countplot(x="pclass", data=data, hue="survived", ax=axes[0,0])
sns.countplot(x="embarked", data=data, hue="survived", ax=axes[0,1])
sns.countplot(x="sex", data=data, hue="survived", ax=axes[1,0])
sns.countplot(x="boat", data=data, hue="survived", ax=axes[1,1])
sns.violinplot(x= 'survived',y='age',data=data, ax=axes[2,0])
sns.boxplot(x= 'survived',y='age',data=data, ax=axes[2,1])

# %% [markdown]
# ### Sobre el analisis gráfico por categorías respecto a la variable objetivo:
# *  Se pued eobservar una clara relación entre el deceso de un ocupante del titanic con su sexo y la clase en la cual estaba ubicado en el barco, además de una clara relación entr el deceso y si estuvo o no en un bote salvavidas.
# * Hay otra relación no tan clara entre el deceso y el puerto en el cual embarcó el pasajero.
# * Como se puede observar en el gráfico de cajas, no existe nada que nos indique que la supervivencia de un pasajero estuviera relacionada con la edad
