# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly
import plotly.express as px

# %% [markdown]
# # 1. Análisis exploratorio
# ## 1.1 Integridad de la información

# %%
winesW= pd.read_csv(r"C:\Users\Usuario\Ciencia de datos\MLPython\python-ml-course-master\datasets\wine\winequality-white.csv", sep=";")
winesR= pd.read_csv(r"C:\Users\Usuario\Ciencia de datos\MLPython\python-ml-course-master\datasets\wine\winequality-red.csv", sep=";")

# %%
print(winesR.columns)
print(winesW.columns)
print(len(winesR))
print(len(winesW))
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
# 1599
# 4898

# %% [markdown]
# Como se puede observar, ambos data sets tienen las mismas columnas, se procederá a unir los dos datasets

# %%
wines= pd.concat([winesR, winesW], ignore_index= True)

# %%
wines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 609.2 KB

# %% [markdown]
# Como primer paso realizo un análisis programático de losd atos, en este caso, teniendo presente que todas las columnas corresponden a caracteristicas de la composición química de un vino en particular, es de esperarse que las variables sean de tipo flotante, es decir, números decimales.
#
# Como la variable "quality" es la correspondiente a la calificación asignada por un catador de vinos, tiene sentido que esta esté dada por números enteros

# %%
wines.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Como se puede observar, las columnas del dataset no presentan valores nulos, por esto, no hay que aplicar ningún tratamiento de datos

# %%
## Exploración visual de los primeros 50 datos para comprobar la integridad de la información
wines.head(50)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# 13            7.8             0.610         0.29             1.6      0.114
# 14            8.9             0.620         0.18             3.8      0.176
# 15            8.9             0.620         0.19             3.9      0.170
# 16            8.5             0.280         0.56             1.8      0.092
# 17            8.1             0.560         0.28             1.7      0.368
# 18            7.4             0.590         0.08             4.4      0.086
# 19            7.9             0.320         0.51             1.8      0.341
# 20            8.9             0.220         0.48             1.8      0.077
# 21            7.6             0.390         0.31             2.3      0.082
# 22            7.9             0.430         0.21             1.6      0.106
# 23            8.5             0.490         0.11             2.3      0.084
# 24            6.9             0.400         0.14             2.4      0.085
# 25            6.3             0.390         0.16             1.4      0.080
# 26            7.6             0.410         0.24             1.8      0.080
# 27            7.9             0.430         0.21             1.6      0.106
# 28            7.1             0.710         0.00             1.9      0.080
# 29            7.8             0.645         0.00             2.0      0.082
# 30            6.7             0.675         0.07             2.4      0.089
# 31            6.9             0.685         0.00             2.5      0.105
# 32            8.3             0.655         0.12             2.3      0.083
# 33            6.9             0.605         0.12            10.7      0.073
# 34            5.2             0.320         0.25             1.8      0.103
# 35            7.8             0.645         0.00             5.5      0.086
# 36            7.8             0.600         0.14             2.4      0.086
# 37            8.1             0.380         0.28             2.1      0.066
# 38            5.7             1.130         0.09             1.5      0.172
# 39            7.3             0.450         0.36             5.9      0.074
# 40            7.3             0.450         0.36             5.9      0.074
# 41            8.8             0.610         0.30             2.8      0.088
# 42            7.5             0.490         0.20             2.6      0.332
# 43            8.1             0.660         0.22             2.2      0.069
# 44            6.8             0.670         0.02             1.8      0.050
# 45            4.6             0.520         0.15             2.1      0.054
# 46            7.7             0.935         0.43             2.2      0.114
# 47            8.7             0.290         0.52             1.6      0.113
# 48            6.4             0.400         0.23             1.6      0.066
# 49            5.6             0.310         0.37             1.4      0.074
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 12                 16.0                  59.0   0.9943  3.58       0.52
# 13                  9.0                  29.0   0.9974  3.26       1.56
# 14                 52.0                 145.0   0.9986  3.16       0.88
# 15                 51.0                 148.0   0.9986  3.17       0.93
# 16                 35.0                 103.0   0.9969  3.30       0.75
# 17                 16.0                  56.0   0.9968  3.11       1.28
# 18                  6.0                  29.0   0.9974  3.38       0.50
# 19                 17.0                  56.0   0.9969  3.04       1.08
# 20                 29.0                  60.0   0.9968  3.39       0.53
# 21                 23.0                  71.0   0.9982  3.52       0.65
# 22                 10.0                  37.0   0.9966  3.17       0.91
# 23                  9.0                  67.0   0.9968  3.17       0.53
# 24                 21.0                  40.0   0.9968  3.43       0.63
# 25                 11.0                  23.0   0.9955  3.34       0.56
# 26                  4.0                  11.0   0.9962  3.28       0.59
# 27                 10.0                  37.0   0.9966  3.17       0.91
# 28                 14.0                  35.0   0.9972  3.47       0.55
# 29                  8.0                  16.0   0.9964  3.38       0.59
# 30                 17.0                  82.0   0.9958  3.35       0.54
# 31                 22.0                  37.0   0.9966  3.46       0.57
# 32                 15.0                 113.0   0.9966  3.17       0.66
# 33                 40.0                  83.0   0.9993  3.45       0.52
# 34                 13.0                  50.0   0.9957  3.38       0.55
# 35                  5.0                  18.0   0.9986  3.40       0.55
# 36                  3.0                  15.0   0.9975  3.42       0.60
# 37                 13.0                  30.0   0.9968  3.23       0.73
# 38                  7.0                  19.0   0.9940  3.50       0.48
# 39                 12.0                  87.0   0.9978  3.33       0.83
# 40                 12.0                  87.0   0.9978  3.33       0.83
# 41                 17.0                  46.0   0.9976  3.26       0.51
# 42                  8.0                  14.0   0.9968  3.21       0.90
# 43                  9.0                  23.0   0.9968  3.30       1.20
# 44                  5.0                  11.0   0.9962  3.48       0.52
# 45                  8.0                  65.0   0.9934  3.90       0.56
# 46                 22.0                 114.0   0.9970  3.25       0.73
# 47                 12.0                  37.0   0.9969  3.25       0.58
# 48                  5.0                  12.0   0.9958  3.34       0.56
# 49                 12.0                  96.0   0.9954  3.32       0.58
#
#     alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 4       9.4        5
# 5       9.4        5
# 6       9.4        5
# 7      10.0        7
# 8       9.5        7
# 9      10.5        5
# 10      9.2        5
# 11     10.5        5
# 12      9.9        5
# 13      9.1        5
# 14      9.2        5
# 15      9.2        5
# 16     10.5        7
# 17      9.3        5
# 18      9.0        4
# 19      9.2        6
# 20      9.4        6
# 21      9.7        5
# 22      9.5        5
# 23      9.4        5
# 24      9.7        6
# 25      9.3        5
# 26      9.5        5
# 27      9.5        5
# 28      9.4        5
# 29      9.8        6
# 30     10.1        5
# 31     10.6        6
# 32      9.8        5
# 33      9.4        6
# 34      9.2        5
# 35      9.6        6
# 36     10.8        6
# 37      9.7        7
# 38      9.8        4
# 39     10.5        5
# 40     10.5        5
# 41      9.3        4
# 42     10.5        6
# 43     10.3        5
# 44      9.5        5
# 45     13.1        4
# 46      9.2        5
# 47      9.5        5
# 48      9.2        5
# 49      9.2        5

# %%
## Exploración visual de los últimos 50 datos para comprobar la integridad de la información
wines.tail(50)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6447            7.0             0.360         0.35            2.50      0.048
# 6448            6.4             0.330         0.44            8.90      0.055
# 6449            7.0             0.360         0.35            2.50      0.048
# 6450            6.4             0.330         0.44            8.90      0.055
# 6451            6.2             0.230         0.38            1.60      0.044
# 6452            5.2             0.250         0.23            1.40      0.047
# 6453            6.2             0.350         0.29            3.90      0.041
# 6454            7.1             0.230         0.39           13.70      0.058
# 6455            7.1             0.230         0.39           13.70      0.058
# 6456            7.5             0.380         0.33            9.20      0.043
# 6457            6.4             0.350         0.51            7.80      0.055
# 6458            6.0             0.430         0.34            7.60      0.045
# 6459            6.0             0.520         0.33            7.70      0.046
# 6460            5.5             0.310         0.29            3.00      0.027
# 6461            5.9             0.220         0.30            1.30      0.052
# 6462            6.2             0.360         0.32            4.00      0.036
# 6463            6.0             0.410         0.23            1.10      0.066
# 6464            6.2             0.355         0.35            2.00      0.046
# 6465            5.7             0.410         0.21            1.90      0.048
# 6466            5.3             0.600         0.34            1.40      0.031
# 6467            5.8             0.230         0.31            4.50      0.046
# 6468            6.6             0.240         0.33           10.10      0.032
# 6469            6.1             0.320         0.28            6.60      0.021
# 6470            5.0             0.200         0.40            1.90      0.015
# 6471            6.0             0.420         0.41           12.40      0.032
# 6472            5.7             0.210         0.32            1.60      0.030
# 6473            5.6             0.200         0.36            2.50      0.048
# 6474            7.4             0.220         0.26            1.20      0.035
# 6475            6.2             0.380         0.42            2.50      0.038
# 6476            5.9             0.540         0.00            0.80      0.032
# 6477            6.2             0.530         0.02            0.90      0.035
# 6478            6.6             0.340         0.40            8.10      0.046
# 6479            6.6             0.340         0.40            8.10      0.046
# 6480            5.0             0.235         0.27           11.75      0.030
# 6481            5.5             0.320         0.13            1.30      0.037
# 6482            4.9             0.470         0.17            1.90      0.035
# 6483            6.5             0.330         0.38            8.30      0.048
# 6484            6.6             0.340         0.40            8.10      0.046
# 6485            6.2             0.210         0.28            5.70      0.028
# 6486            6.2             0.410         0.22            1.90      0.023
# 6487            6.8             0.220         0.36            1.20      0.052
# 6488            4.9             0.235         0.27           11.75      0.030
# 6489            6.1             0.340         0.29            2.20      0.036
# 6490            5.7             0.210         0.32            0.90      0.038
# 6491            6.5             0.230         0.38            1.30      0.032
# 6492            6.2             0.210         0.29            1.60      0.039
# 6493            6.6             0.320         0.36            8.00      0.047
# 6494            6.5             0.240         0.19            1.20      0.041
# 6495            5.5             0.290         0.30            1.10      0.022
# 6496            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6447                 67.0                 161.0  0.99146  3.05       0.56
# 6448                 52.0                 164.0  0.99488  3.10       0.48
# 6449                 67.0                 161.0  0.99146  3.05       0.56
# 6450                 52.0                 164.0  0.99488  3.10       0.48
# 6451                 12.0                 113.0  0.99176  3.30       0.73
# 6452                 20.0                  77.0  0.99001  3.32       0.62
# 6453                 22.0                  79.0  0.99005  3.10       0.59
# 6454                 26.0                 172.0  0.99755  2.90       0.46
# 6455                 26.0                 172.0  0.99755  2.90       0.46
# 6456                 19.0                 116.0  0.99444  3.08       0.42
# 6457                 53.0                 177.0  0.99502  3.12       0.45
# 6458                 25.0                 118.0  0.99222  3.03       0.37
# 6459                 24.0                 119.0  0.99224  3.04       0.38
# 6460                 16.0                 102.0  0.99067  3.23       0.56
# 6461                 42.0                  86.0  0.99069  3.31       0.47
# 6462                 44.0                  92.0  0.98936  3.20       0.50
# 6463                 22.0                 148.0  0.99266  3.30       0.47
# 6464                 31.0                  95.0  0.98822  3.06       0.46
# 6465                 30.0                 112.0  0.99138  3.29       0.55
# 6466                  3.0                  60.0  0.98854  3.27       0.38
# 6467                 42.0                 124.0  0.99324  3.31       0.64
# 6468                  8.0                  81.0  0.99626  3.19       0.51
# 6469                 29.0                 132.0  0.99188  3.15       0.36
# 6470                 20.0                  98.0  0.98970  3.37       0.55
# 6471                 50.0                 179.0  0.99622  3.14       0.60
# 6472                 33.0                 122.0  0.99044  3.33       0.52
# 6473                 16.0                 125.0  0.99282  3.49       0.49
# 6474                 18.0                  97.0  0.99245  3.12       0.41
# 6475                 34.0                 117.0  0.99132  3.36       0.59
# 6476                 12.0                  82.0  0.99286  3.25       0.36
# 6477                  6.0                  81.0  0.99234  3.24       0.35
# 6478                 68.0                 170.0  0.99494  3.15       0.50
# 6479                 68.0                 170.0  0.99494  3.15       0.50
# 6480                 34.0                 118.0  0.99540  3.07       0.50
# 6481                 45.0                 156.0  0.99184  3.26       0.38
# 6482                 60.0                 148.0  0.98964  3.27       0.35
# 6483                 68.0                 174.0  0.99492  3.14       0.50
# 6484                 68.0                 170.0  0.99494  3.15       0.50
# 6485                 45.0                 121.0  0.99168  3.21       1.08
# 6486                  5.0                  56.0  0.98928  3.04       0.79
# 6487                 38.0                 127.0  0.99330  3.04       0.54
# 6488                 34.0                 118.0  0.99540  3.07       0.50
# 6489                 25.0                 100.0  0.98938  3.06       0.44
# 6490                 38.0                 121.0  0.99074  3.24       0.46
# 6491                 29.0                 112.0  0.99298  3.29       0.54
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#         alcohol  quality
# 6447  11.100000        6
# 6448   9.600000        5
# 6449  11.100000        6
# 6450   9.600000        5
# 6451  11.400000        5
# 6452  11.400000        5
# 6453  12.066667        6
# 6454   9.000000        6
# 6455   9.000000        6
# 6456  11.400000        6
# 6457   9.600000        5
# 6458  11.000000        6
# 6459  11.000000        6
# 6460  11.200000        6
# 6461  11.550000        6
# 6462  13.300000        7
# 6463   9.633333        5
# 6464  13.600000        6
# 6465  11.200000        6
# 6466  13.000000        6
# 6467  10.800000        6
# 6468   9.800000        6
# 6469  11.450000        7
# 6470  12.050000        6
# 6471   9.700000        5
# 6472  11.900000        6
# 6473  10.000000        6
# 6474   9.700000        6
# 6475  11.600000        7
# 6476   8.800000        5
# 6477   9.500000        4
# 6478   9.533333        6
# 6479   9.533333        6
# 6480   9.400000        6
# 6481  10.700000        5
# 6482  11.500000        6
# 6483   9.600000        5
# 6484   9.550000        6
# 6485  12.150000        7
# 6486  13.000000        7
# 6487   9.200000        5
# 6488   9.400000        6
# 6489  11.800000        6
# 6490  10.600000        6
# 6491   9.700000        5
# 6492  11.200000        6
# 6493   9.600000        5
# 6494   9.400000        6
# 6495  12.800000        7
# 6496  11.800000        6

# %% [markdown]
# Con la finalidad de comprender con mejor profundidad nuestro problema, es importante entender que tan balanceada esta la muestra, en este caso nuestra clasificación es la supervivencia (columna "quality"), la cual puede tomar solamente valores enteros comprendidos, en este caso entre 3 y 9

# %%
wines.quality.value_counts()
# Out:
# 6    2836
# 5    2138
# 7    1079
# 4     216
# 8     193
# 3      30
# 9       5
# Name: quality, dtype: int64

# %% [markdown]
# Se puede observar que las categorías no están balanceadas, teniendo en cuenta esto, se decidirá si balancear por medio de algún método de muestreo el dataset dependiendo del resultado de la primera iteración del modelo

# %% [markdown]
# ## 1.2 Entendimiento del sistema
#
# En este caso particular, las variables de estudio no son temporales, represnetan en su totalidad mediciones de las propiedades químicas de una cantidad de vinos de diferentes fuentes, al mismo tiempo la calificación otorgada por un experto .
# El conocimiento del origen de la información y su significado nos ayuda a encaminar de manera adecuada el tratamiento de datos.

# %%
f, axes = plt.subplots(4, 3, figsize=(18, 24))
k=int(np.ceil(1+ np.log2(len(wines))))
sns.distplot(wines['fixed acidity'], bins= k, kde=True, ax= axes[0,0])
sns.distplot(wines['volatile acidity'], bins= k, kde=True, ax= axes[0,1])
sns.distplot(wines['citric acid'], bins= k, kde=True, ax= axes[0,2])
sns.distplot(wines['residual sugar'], bins= k, kde=True, ax= axes[1,0])
sns.distplot(wines['chlorides'], bins= k, kde=True, ax= axes[1,1])
sns.distplot(wines['free sulfur dioxide'], bins= k, kde=True, ax= axes[1,2])
sns.distplot(wines['total sulfur dioxide'], bins= k, kde=True, ax= axes[2,0])
sns.distplot(wines['density'], bins= k, kde=True, ax= axes[2,1])
sns.distplot(wines['pH'], bins= k, kde=True, ax= axes[2,2])
sns.distplot(wines['sulphates'], bins= k, kde=True, ax= axes[3,0])
sns.distplot(wines['alcohol'], bins= k, kde=True, ax= axes[3,1])
sns.distplot(wines['quality'], bins= 7, kde=True, ax= axes[3,2])

# %% [markdown]
# En las gráficas presentadas anteriormente se puede ver la distribución de los datos para cada una de las diferentes variables, en este caso, como los datos corresponden a caracteristicas químicas de cada una de las bebidas, en la medida que se avance en el entendimiento del sistema, se podrá observar con mayor claridad como influye cada una de estas sobre la variable objetivo "quality"
#
#
# ### Resumen diagnostico del data set:
# * El contenido del dataset es de buena calidad, no tiene valores vacíos, tiene una buena cantidad de datos, aunque no son suficientes para un modelo de DL, podríamos intentar un modelo de ensamblaje en caso tal de no estar satisfechos con el desempeño del modelo.
# * La variable objetivo no está balanceada, sin embargo, como se puede observar la distribución normal en la misma, las calificaciónes menos repetidas en el dataset deberían depender enteramente de los outliers o valores atípicos que se puedan evidenciar más adelante.
# * Las distribuciones no tienen colas pesadas en su mayoría, sin embargo algunas de las variables tienen colas largas

# %% [markdown]
# # 2. Examinación estadistica
# ## 2.1 Descripción básica

# %%
#Descripción de las variables numericas
wines.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# min       0.009000             1.000000              6.000000     0.987110
# 25%       0.038000            17.000000             77.000000     0.992340
# 50%       0.047000            29.000000            118.000000     0.994890
# 75%       0.065000            41.000000            156.000000     0.996990
# max       0.611000           289.000000            440.000000     1.038980
#
#                 pH    sulphates      alcohol      quality
# count  6497.000000  6497.000000  6497.000000  6497.000000
# mean      3.218501     0.531268    10.491801     5.818378
# std       0.160787     0.148806     1.192712     0.873255
# min       2.720000     0.220000     8.000000     3.000000
# 25%       3.110000     0.430000     9.500000     5.000000
# 50%       3.210000     0.510000    10.300000     6.000000
# 75%       3.320000     0.600000    11.300000     6.000000
# max       4.010000     2.000000    14.900000     9.000000

# %% [markdown]
# #### Hechos para resaltar:
# * La dispersión para las variables "volatile acidity", "citric acidity", "residual sugar", "chlorides", "free sulfur dioxide" y "total sulfur dioxide" la dispersión es considerable, entre un 40% y un 50% para las variables mencionadas, para las demás variables del dataset la dispersión es poca.
# * El conteo de variables es homogeneo, no hay datos faltantes para ningúna de las variables.

# %% [markdown]
# ## 2.2 Análisis gráfico y análisis de correlación
#
# Para facilitar la interpretación del gráfico de estados, seleccionaré solamente las variables que están más correlacionadas con la variable de salida
#
# ### 2.2.1 Análisis de correlación

# %%
f, axes =plt.subplots(figsize=(20,20))
sns.heatmap(wines.corr(), square=True, annot=True).set_title('Correlaciones')
# Out:
# Text(0.5, 1.0, 'Correlaciones')

# %% [markdown]
# ### Conclusiones sobre la correlación:
# * Se puede observar del dataset que la calidad con la cual fue calificada el producto está estrechamente relacionada con las siguientes columnas "alcohol", "clorides", "density" y "volatile acidity".
# * Como se puede observar, algunas de las variables diferentes a la variable objetivo están relacionadas entre si, para no sobrecargar el modelo con variables que sean redundantes, se estudiará más adelante la importancia de cada una de las variables en el modelo.
#
# ### 2.2.2 Análisis Gráfico

# %%
matters =["volatile acidity", "chlorides","density", "alcohol", "citric acid",
          "residual sugar", "free sulfur dioxide", "total sulfur dioxide"]
sns.pairplot(data= wines,vars = matters, hue='quality')

# %%
ax= plt.figure(figsize=(8, 8)).add_subplot(111, projection ='3d')
wines['colors'] = wines['quality']
ax.scatter(wines['volatile acidity'], wines['chlorides'], wines['total sulfur dioxide'], c=wines['colors'])
ax.set_xlabel('volatile acidity')
ax.set_ylabel('alcohol')
ax.set_zlabel('total sulfur dioxide')
plt.show()

ax= plt.figure(figsize=(8, 8)).add_subplot(111, projection ='3d')
wines['colors'] = wines['quality']
ax.scatter(wines['volatile acidity'], wines['alcohol'], wines['citric acid'], c=wines['colors'])
ax.set_xlabel('volatile acidity')
ax.set_ylabel('alcohol')
ax.set_zlabel('citric acid')
plt.show()

ax= plt.figure(figsize=(8, 8)).add_subplot(111, projection ='3d')
wines['colors'] = wines['quality']
ax.scatter(wines['volatile acidity'], wines['chlorides'], wines['density'], c=wines['colors'])
ax.set_xlabel('volatile acidity')
ax.set_ylabel('chlorides')
ax.set_zlabel('density')
plt.show()

ax= plt.figure(figsize=(8, 8)).add_subplot(111, projection ='3d')
wines['colors'] = wines['quality']
ax.scatter(wines['residual sugar'], wines['alcohol'], wines['free sulfur dioxide'], c=wines['colors'])
ax.set_xlabel('volatile acidity')
ax.set_ylabel('chlorides')
ax.set_zlabel('density')
plt.show()

# %%
plotly.offline.init_notebook_mode(connected=True)
fig = px.scatter_3d(wines, x='volatile acidity', y='alcohol', z='total sulfur dioxide',
              color='quality')
#fig.write_html("animacion1_3D.html")
fig.show()

plotly.offline.init_notebook_mode(connected=True)
fig = px.scatter_3d(wines, x='volatile acidity', y='alcohol', z='citric acid',
              color='quality')
#fig.write_html("animacion1_3D.html")
fig.show()

plotly.offline.init_notebook_mode(connected=True)
fig = px.scatter_3d(wines, x='volatile acidity', y='chlorides', z='density',
              color='quality')
#fig.write_html("animacion1_3D.html")
fig.show()

plotly.offline.init_notebook_mode(connected=True)
fig = px.scatter_3d(wines, x='residual sugar', y='alcohol', z='free sulfur dioxide',
              color='quality')
#fig.write_html("animacion1_3D.html")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="485fca5c-ed1e-4563-8549-39aff58e209a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("485fca5c-ed1e-4563-8549-39aff58e209a")) {                    Plotly.newPlot(                        "485fca5c-ed1e-4563-8549-39aff58e209a",                        [{"hovertemplate": "volatile acidity=%{x}<br>alcohol=%{y}<br>total sulfur dioxide=%{z}<br>quality=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 6, 6, 7, 4, 5, 5, 4, 6, 5, 5, 4, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 7, 5, 5, 5, 5, 5, 5, 6, 6, 5, 5, 4, 5, 5, 5, 6, 5, 4, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 4, 6, 5, 5, 5, 6, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 6, 6, 6, 4, 5, 5, 5, 5, 5, 5, 5, 6, 5, 4, 6, 5, 5, 5, 5, 4, 6, 5, 4, 6, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 6, 7, 4, 7, 5, 5, 5, 6, 7, 7, 5, 5, 7, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 6, 4, 6, 6, 5, 6, 5, 7, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6, 6, 7, 7, 6, 5, 5, 6, 6, 6, 6, 5, 5, 6, 5, 5, 5, 5, 7, 5, 4, 5, 5, 5, 7, 4, 8, 6, 6, 6, 6, 5, 5, 5, 6, 6, 6, 8, 7, 6, 7, 5, 7, 5, 5, 6, 6, 7, 5, 7, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 6, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 6, 5, 5, 6, 5, 6, 7, 6, 7, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 6, 6, 5, 7, 7, 6, 5, 6, 7, 6, 6, 6, 6, 6, 5, 7, 6, 6, 6, 6, 6, 5, 5, 6, 6, 5, 7, 7, 6, 5, 6, 5, 5, 7, 6, 7, 5, 5, 7, 5, 6, 6, 5, 6, 7, 6, 7, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 6, 7, 8, 6, 5, 5, 5, 7, 5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 6, 7, 6, 4, 6, 5, 5, 7, 5, 5, 6, 5, 6, 5, 7, 7, 5, 7, 5, 7, 6, 6, 5, 6, 7, 5, 6, 5, 6, 5, 6, 6, 6, 5, 8, 6, 7, 7, 7, 6, 5, 5, 6, 6, 6, 6, 6, 7, 5, 8, 5, 5, 7, 3, 6, 5, 5, 5, 6, 5, 6, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 6, 5, 6, 5, 8, 5, 5, 6, 5, 5, 6, 7, 6, 6, 7, 7, 6, 6, 8, 6, 5, 8, 6, 6, 7, 7, 7, 7, 7, 7, 6, 6, 7, 5, 6, 6, 7, 7, 5, 6, 3, 6, 5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 6, 6, 6, 5, 6, 7, 5, 5, 6, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 6, 5, 5, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 4, 6, 6, 4, 5, 5, 6, 5, 5, 5, 7, 7, 6, 7, 5, 8, 7, 5, 6, 5, 5, 5, 5, 6, 6, 6, 6, 4, 6, 5, 6, 6, 6, 7, 6, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 4, 5, 5, 5, 5, 7, 6, 5, 5, 5, 5, 5, 7, 5, 4, 7, 6, 5, 5, 5, 6, 5, 5, 5, 7, 6, 4, 6, 5, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 3, 5, 5, 5, 5, 6, 6, 6, 5, 6, 6, 6, 6, 4, 4, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 4, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 5, 6, 5, 5, 5, 5, 6, 6, 5, 6, 6, 5, 5, 5, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 6, 5, 6, 5, 5, 7, 6, 6, 5, 5, 7, 6, 6, 7, 7, 7, 5, 6, 5, 6, 5, 4, 6, 5, 6, 6, 5, 5, 5, 7, 5, 5, 5, 5, 7, 5, 8, 6, 4, 6, 3, 4, 5, 5, 7, 7, 7, 5, 7, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 6, 7, 6, 7, 7, 6, 5, 6, 5, 5, 5, 5, 6, 6, 6, 6, 6, 5, 4, 7, 7, 7, 4, 6, 6, 5, 5, 6, 6, 5, 6, 5, 6, 7, 6, 5, 5, 5, 6, 5, 6, 6, 7, 6, 7, 3, 5, 7, 7, 7, 7, 5, 5, 6, 6, 6, 6, 6, 6, 7, 6, 6, 5, 6, 6, 6, 5, 6, 6, 6, 5, 7, 6, 4, 5, 7, 5, 5, 6, 5, 5, 6, 6, 4, 7, 5, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 6, 5, 6, 6, 7, 5, 6, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 6, 7, 5, 7, 5, 5, 5, 7, 5, 6, 5, 6, 6, 5, 6, 7, 5, 5, 6, 5, 5, 6, 5, 5, 6, 7, 7, 6, 6, 7, 7, 7, 7, 5, 7, 7, 7, 7, 5, 7, 6, 5, 6, 6, 6, 7, 6, 6, 5, 6, 6, 5, 6, 7, 6, 6, 5, 6, 7, 7, 7, 5, 6, 6, 7, 7, 5, 7, 6, 5, 6, 6, 7, 6, 6, 6, 5, 6, 6, 5, 5, 5, 7, 6, 6, 7, 5, 7, 7, 6, 8, 6, 6, 6, 6, 7, 7, 7, 5, 7, 5, 6, 6, 5, 7, 6, 5, 5, 7, 6, 7, 6, 6, 6, 5, 7, 6, 7, 7, 8, 6, 6, 7, 6, 5, 6, 5, 7, 5, ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6665b11b-7344-4280-abff-bf196626694c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6665b11b-7344-4280-abff-bf196626694c")) {                    Plotly.newPlot(                        "6665b11b-7344-4280-abff-bf196626694c",                        [{"hovertemplate": "volatile acidity=%{x}<br>alcohol=%{y}<br>citric acid=%{z}<br>quality=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 6, 6, 7, 4, 5, 5, 4, 6, 5, 5, 4, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 7, 5, 5, 5, 5, 5, 5, 6, 6, 5, 5, 4, 5, 5, 5, 6, 5, 4, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 4, 6, 5, 5, 5, 6, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 6, 6, 6, 4, 5, 5, 5, 5, 5, 5, 5, 6, 5, 4, 6, 5, 5, 5, 5, 4, 6, 5, 4, 6, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 6, 7, 4, 7, 5, 5, 5, 6, 7, 7, 5, 5, 7, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 6, 4, 6, 6, 5, 6, 5, 7, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6, 6, 7, 7, 6, 5, 5, 6, 6, 6, 6, 5, 5, 6, 5, 5, 5, 5, 7, 5, 4, 5, 5, 5, 7, 4, 8, 6, 6, 6, 6, 5, 5, 5, 6, 6, 6, 8, 7, 6, 7, 5, 7, 5, 5, 6, 6, 7, 5, 7, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 6, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 6, 5, 5, 6, 5, 6, 7, 6, 7, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 6, 6, 5, 7, 7, 6, 5, 6, 7, 6, 6, 6, 6, 6, 5, 7, 6, 6, 6, 6, 6, 5, 5, 6, 6, 5, 7, 7, 6, 5, 6, 5, 5, 7, 6, 7, 5, 5, 7, 5, 6, 6, 5, 6, 7, 6, 7, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 6, 7, 8, 6, 5, 5, 5, 7, 5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 6, 7, 6, 4, 6, 5, 5, 7, 5, 5, 6, 5, 6, 5, 7, 7, 5, 7, 5, 7, 6, 6, 5, 6, 7, 5, 6, 5, 6, 5, 6, 6, 6, 5, 8, 6, 7, 7, 7, 6, 5, 5, 6, 6, 6, 6, 6, 7, 5, 8, 5, 5, 7, 3, 6, 5, 5, 5, 6, 5, 6, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 6, 5, 6, 5, 8, 5, 5, 6, 5, 5, 6, 7, 6, 6, 7, 7, 6, 6, 8, 6, 5, 8, 6, 6, 7, 7, 7, 7, 7, 7, 6, 6, 7, 5, 6, 6, 7, 7, 5, 6, 3, 6, 5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 6, 6, 6, 5, 6, 7, 5, 5, 6, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 6, 5, 5, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 4, 6, 6, 4, 5, 5, 6, 5, 5, 5, 7, 7, 6, 7, 5, 8, 7, 5, 6, 5, 5, 5, 5, 6, 6, 6, 6, 4, 6, 5, 6, 6, 6, 7, 6, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 4, 5, 5, 5, 5, 7, 6, 5, 5, 5, 5, 5, 7, 5, 4, 7, 6, 5, 5, 5, 6, 5, 5, 5, 7, 6, 4, 6, 5, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 3, 5, 5, 5, 5, 6, 6, 6, 5, 6, 6, 6, 6, 4, 4, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 4, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 5, 6, 5, 5, 5, 5, 6, 6, 5, 6, 6, 5, 5, 5, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 6, 5, 6, 5, 5, 7, 6, 6, 5, 5, 7, 6, 6, 7, 7, 7, 5, 6, 5, 6, 5, 4, 6, 5, 6, 6, 5, 5, 5, 7, 5, 5, 5, 5, 7, 5, 8, 6, 4, 6, 3, 4, 5, 5, 7, 7, 7, 5, 7, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 6, 7, 6, 7, 7, 6, 5, 6, 5, 5, 5, 5, 6, 6, 6, 6, 6, 5, 4, 7, 7, 7, 4, 6, 6, 5, 5, 6, 6, 5, 6, 5, 6, 7, 6, 5, 5, 5, 6, 5, 6, 6, 7, 6, 7, 3, 5, 7, 7, 7, 7, 5, 5, 6, 6, 6, 6, 6, 6, 7, 6, 6, 5, 6, 6, 6, 5, 6, 6, 6, 5, 7, 6, 4, 5, 7, 5, 5, 6, 5, 5, 6, 6, 4, 7, 5, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 6, 5, 6, 6, 7, 5, 6, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 6, 7, 5, 7, 5, 5, 5, 7, 5, 6, 5, 6, 6, 5, 6, 7, 5, 5, 6, 5, 5, 6, 5, 5, 6, 7, 7, 6, 6, 7, 7, 7, 7, 5, 7, 7, 7, 7, 5, 7, 6, 5, 6, 6, 6, 7, 6, 6, 5, 6, 6, 5, 6, 7, 6, 6, 5, 6, 7, 7, 7, 5, 6, 6, 7, 7, 5, 7, 6, 5, 6, 6, 7, 6, 6, 6, 5, 6, 6, 5, 5, 5, 7, 6, 6, 7, 5, 7, 7, 6, 8, 6, 6, 6, 6, 7, 7, 7, 5, 7, 5, 6, 6, 5, 7, 6, 5, 5, 7, 6, 7, 6, 6, 6, 5, 7, 6, 7, 7, 8, 6, 6, 7, 6, 5, 6, 5, 7, 5, 6, 6, 6, ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="0e7e61d7-296b-41ba-a690-4f9fe95ae1e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e7e61d7-296b-41ba-a690-4f9fe95ae1e3")) {                    Plotly.newPlot(                        "0e7e61d7-296b-41ba-a690-4f9fe95ae1e3",                        [{"hovertemplate": "volatile acidity=%{x}<br>chlorides=%{y}<br>density=%{z}<br>quality=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 6, 6, 7, 4, 5, 5, 4, 6, 5, 5, 4, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 7, 5, 5, 5, 5, 5, 5, 6, 6, 5, 5, 4, 5, 5, 5, 6, 5, 4, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 4, 6, 5, 5, 5, 6, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 6, 6, 6, 4, 5, 5, 5, 5, 5, 5, 5, 6, 5, 4, 6, 5, 5, 5, 5, 4, 6, 5, 4, 6, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 6, 7, 4, 7, 5, 5, 5, 6, 7, 7, 5, 5, 7, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 6, 4, 6, 6, 5, 6, 5, 7, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6, 6, 7, 7, 6, 5, 5, 6, 6, 6, 6, 5, 5, 6, 5, 5, 5, 5, 7, 5, 4, 5, 5, 5, 7, 4, 8, 6, 6, 6, 6, 5, 5, 5, 6, 6, 6, 8, 7, 6, 7, 5, 7, 5, 5, 6, 6, 7, 5, 7, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 6, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 6, 5, 5, 6, 5, 6, 7, 6, 7, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 6, 6, 5, 7, 7, 6, 5, 6, 7, 6, 6, 6, 6, 6, 5, 7, 6, 6, 6, 6, 6, 5, 5, 6, 6, 5, 7, 7, 6, 5, 6, 5, 5, 7, 6, 7, 5, 5, 7, 5, 6, 6, 5, 6, 7, 6, 7, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 6, 7, 8, 6, 5, 5, 5, 7, 5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 6, 7, 6, 4, 6, 5, 5, 7, 5, 5, 6, 5, 6, 5, 7, 7, 5, 7, 5, 7, 6, 6, 5, 6, 7, 5, 6, 5, 6, 5, 6, 6, 6, 5, 8, 6, 7, 7, 7, 6, 5, 5, 6, 6, 6, 6, 6, 7, 5, 8, 5, 5, 7, 3, 6, 5, 5, 5, 6, 5, 6, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 6, 5, 6, 5, 8, 5, 5, 6, 5, 5, 6, 7, 6, 6, 7, 7, 6, 6, 8, 6, 5, 8, 6, 6, 7, 7, 7, 7, 7, 7, 6, 6, 7, 5, 6, 6, 7, 7, 5, 6, 3, 6, 5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 6, 6, 6, 5, 6, 7, 5, 5, 6, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 6, 5, 5, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 4, 6, 6, 4, 5, 5, 6, 5, 5, 5, 7, 7, 6, 7, 5, 8, 7, 5, 6, 5, 5, 5, 5, 6, 6, 6, 6, 4, 6, 5, 6, 6, 6, 7, 6, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 4, 5, 5, 5, 5, 7, 6, 5, 5, 5, 5, 5, 7, 5, 4, 7, 6, 5, 5, 5, 6, 5, 5, 5, 7, 6, 4, 6, 5, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 3, 5, 5, 5, 5, 6, 6, 6, 5, 6, 6, 6, 6, 4, 4, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 4, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 5, 6, 5, 5, 5, 5, 6, 6, 5, 6, 6, 5, 5, 5, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 6, 5, 6, 5, 5, 7, 6, 6, 5, 5, 7, 6, 6, 7, 7, 7, 5, 6, 5, 6, 5, 4, 6, 5, 6, 6, 5, 5, 5, 7, 5, 5, 5, 5, 7, 5, 8, 6, 4, 6, 3, 4, 5, 5, 7, 7, 7, 5, 7, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 6, 7, 6, 7, 7, 6, 5, 6, 5, 5, 5, 5, 6, 6, 6, 6, 6, 5, 4, 7, 7, 7, 4, 6, 6, 5, 5, 6, 6, 5, 6, 5, 6, 7, 6, 5, 5, 5, 6, 5, 6, 6, 7, 6, 7, 3, 5, 7, 7, 7, 7, 5, 5, 6, 6, 6, 6, 6, 6, 7, 6, 6, 5, 6, 6, 6, 5, 6, 6, 6, 5, 7, 6, 4, 5, 7, 5, 5, 6, 5, 5, 6, 6, 4, 7, 5, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 6, 5, 6, 6, 7, 5, 6, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 6, 7, 5, 7, 5, 5, 5, 7, 5, 6, 5, 6, 6, 5, 6, 7, 5, 5, 6, 5, 5, 6, 5, 5, 6, 7, 7, 6, 6, 7, 7, 7, 7, 5, 7, 7, 7, 7, 5, 7, 6, 5, 6, 6, 6, 7, 6, 6, 5, 6, 6, 5, 6, 7, 6, 6, 5, 6, 7, 7, 7, 5, 6, 6, 7, 7, 5, 7, 6, 5, 6, 6, 7, 6, 6, 6, 5, 6, 6, 5, 5, 5, 7, 6, 6, 7, 5, 7, 7, 6, 8, 6, 6, 6, 6, 7, 7, 7, 5, 7, 5, 6, 6, 5, 7, 6, 5, 5, 7, 6, 7, 6, 6, 6, 5, 7, 6, 7, 7, 8, 6, 6, 7, 6, 5, 6, 5, 7, 5, 6, 6, 6, 6 ...
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="557125d6-08a4-444b-bc90-8d6b7fb2b057" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("557125d6-08a4-444b-bc90-8d6b7fb2b057")) {                    Plotly.newPlot(                        "557125d6-08a4-444b-bc90-8d6b7fb2b057",                        [{"hovertemplate": "residual sugar=%{x}<br>alcohol=%{y}<br>free sulfur dioxide=%{z}<br>quality=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [5, 5, 5, 6, 5, 5, 5, 7, 7, 5, 5, 5, 5, 5, 5, 5, 7, 5, 4, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 5, 6, 6, 7, 4, 5, 5, 4, 6, 5, 5, 4, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 7, 5, 5, 5, 5, 5, 5, 6, 6, 5, 5, 4, 5, 5, 5, 6, 5, 4, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 4, 6, 5, 5, 5, 6, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 5, 7, 5, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 6, 6, 6, 4, 5, 5, 5, 5, 5, 5, 5, 6, 5, 4, 6, 5, 5, 5, 5, 4, 6, 5, 4, 6, 6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 6, 7, 4, 7, 5, 5, 5, 6, 7, 7, 5, 5, 7, 6, 6, 6, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 6, 4, 6, 6, 5, 6, 5, 7, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 6, 6, 7, 7, 6, 5, 5, 6, 6, 6, 6, 5, 5, 6, 5, 5, 5, 5, 7, 5, 4, 5, 5, 5, 7, 4, 8, 6, 6, 6, 6, 5, 5, 5, 6, 6, 6, 8, 7, 6, 7, 5, 7, 5, 5, 6, 6, 7, 5, 7, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 6, 5, 5, 5, 6, 5, 6, 6, 6, 6, 6, 6, 5, 5, 6, 5, 6, 7, 6, 7, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 6, 6, 5, 7, 7, 6, 5, 6, 7, 6, 6, 6, 6, 6, 5, 7, 6, 6, 6, 6, 6, 5, 5, 6, 6, 5, 7, 7, 6, 5, 6, 5, 5, 7, 6, 7, 5, 5, 7, 5, 6, 6, 5, 6, 7, 6, 7, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 6, 7, 8, 6, 5, 5, 5, 7, 5, 6, 6, 5, 5, 6, 6, 6, 5, 6, 6, 7, 6, 4, 6, 5, 5, 7, 5, 5, 6, 5, 6, 5, 7, 7, 5, 7, 5, 7, 6, 6, 5, 6, 7, 5, 6, 5, 6, 5, 6, 6, 6, 5, 8, 6, 7, 7, 7, 6, 5, 5, 6, 6, 6, 6, 6, 7, 5, 8, 5, 5, 7, 3, 6, 5, 5, 5, 6, 5, 6, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 6, 5, 6, 5, 8, 5, 5, 6, 5, 5, 6, 7, 6, 6, 7, 7, 6, 6, 8, 6, 5, 8, 6, 6, 7, 7, 7, 7, 7, 7, 6, 6, 7, 5, 6, 6, 7, 7, 5, 6, 3, 6, 5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 6, 6, 6, 5, 6, 7, 5, 5, 6, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 6, 5, 5, 5, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5, 6, 6, 6, 6, 6, 6, 5, 4, 6, 6, 4, 5, 5, 6, 5, 5, 5, 7, 7, 6, 7, 5, 8, 7, 5, 6, 5, 5, 5, 5, 6, 6, 6, 6, 4, 6, 5, 6, 6, 6, 7, 6, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 6, 4, 5, 5, 5, 5, 7, 6, 5, 5, 5, 5, 5, 7, 5, 4, 7, 6, 5, 5, 5, 6, 5, 5, 5, 7, 6, 4, 6, 5, 6, 6, 5, 5, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 6, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 3, 5, 5, 5, 5, 6, 6, 6, 5, 6, 6, 6, 6, 4, 4, 5, 5, 5, 6, 6, 5, 5, 5, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 5, 4, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 5, 6, 5, 5, 6, 5, 5, 5, 5, 6, 6, 5, 6, 6, 5, 5, 5, 5, 6, 6, 6, 5, 5, 5, 5, 5, 6, 5, 6, 6, 5, 5, 6, 5, 6, 5, 5, 6, 6, 5, 6, 6, 5, 5, 6, 5, 5, 5, 5, 5, 5, 6, 6, 5, 6, 5, 6, 5, 6, 5, 5, 7, 6, 6, 5, 5, 7, 6, 6, 7, 7, 7, 5, 6, 5, 6, 5, 4, 6, 5, 6, 6, 5, 5, 5, 7, 5, 5, 5, 5, 7, 5, 8, 6, 4, 6, 3, 4, 5, 5, 7, 7, 7, 5, 7, 5, 6, 5, 6, 5, 5, 6, 5, 5, 5, 5, 5, 6, 6, 7, 6, 7, 7, 6, 5, 6, 5, 5, 5, 5, 6, 6, 6, 6, 6, 5, 4, 7, 7, 7, 4, 6, 6, 5, 5, 6, 6, 5, 6, 5, 6, 7, 6, 5, 5, 5, 6, 5, 6, 6, 7, 6, 7, 3, 5, 7, 7, 7, 7, 5, 5, 6, 6, 6, 6, 6, 6, 7, 6, 6, 5, 6, 6, 6, 5, 6, 6, 6, 5, 7, 6, 4, 5, 7, 5, 5, 6, 5, 5, 6, 6, 4, 7, 5, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 6, 5, 6, 6, 7, 5, 6, 5, 5, 6, 6, 6, 7, 5, 6, 5, 6, 6, 7, 5, 7, 5, 5, 5, 7, 5, 6, 5, 6, 6, 5, 6, 7, 5, 5, 6, 5, 5, 6, 5, 5, 6, 7, 7, 6, 6, 7, 7, 7, 7, 5, 7, 7, 7, 7, 5, 7, 6, 5, 6, 6, 6, 7, 6, 6, 5, 6, 6, 5, 6, 7, 6, 6, 5, 6, 7, 7, 7, 5, 6, 6, 7, 7, 5, 7, 6, 5, 6, 6, 7, 6, 6, 6, 5, 6, 6, 5, 5, 5, 7, 6, 6, 7, 5, 7, 7, 6, 8, 6, 6, 6, 6, 7, 7, 7, 5, 7, 5, 6, 6, 5, 7, 6, 5, 5, 7, 6, 7, 6, 6, 6, 5, 7, 6, 7, 7, 8, 6, 6, 7, 6, 5, 6, 5, 7, 5, 6, ...

# %% [markdown]
# ### Conclusiones de las gráficas en 3D:
#
# De las gráficas anteriores podemos notar que la calificación de calidad del vino está directamente ligada con una baja cantidad de "chlorids", una baja cantidad de "volatile acidity" y mejora su calificación a medida que va aumentando los grados de alcohol que este tiene.
#
# Por la naturaleza observada en los datos en los gráficos 3D, es posible pensar que un modelo de KNN, un modelo de RVF SVM o un modelo de random forest podrían tener un buen desempeño en la clasificación.
